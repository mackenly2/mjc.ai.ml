# %% [markdown]
# <a href="https://colab.research.google.com/github/bjungweapon/mjc.ai.ml/blob/BDU/bud.6.1.%EA%B2%B0%EC%B8%A1%EC%B9%98%EB%B6%84%EC%84%9D.titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. 결측치 확인 방법
#   . (isnull)
#
#    . 데이터 프레임에서 결측치는 일반적으로 NaN으로 표시

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("http://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %% [markdown]
# 1. 결측치가 있는지를 확인 하자.
#   (결측치 )

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
## 결측치가 있으면  True,  없으면 False를 출력.

df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
df.notnull()
# Out:
#      PassengerId  Survived  Pclass  Name   Sex    Age  SibSp  Parch  Ticket  \
# 0           True      True    True  True  True   True   True   True    True
# 1           True      True    True  True  True   True   True   True    True
# 2           True      True    True  True  True   True   True   True    True
# 3           True      True    True  True  True   True   True   True    True
# 4           True      True    True  True  True   True   True   True    True
# ..           ...       ...     ...   ...   ...    ...    ...    ...     ...
# 886         True      True    True  True  True   True   True   True    True
# 887         True      True    True  True  True   True   True   True    True
# 888         True      True    True  True  True  False   True   True    True
# 889         True      True    True  True  True   True   True   True    True
# 890         True      True    True  True  True   True   True   True    True
#
#      Fare  Cabin  Embarked
# 0    True  False      True
# ...

# %%
## isnull(), sum()를 잉요하여 결측치 갯수 파악

df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
#  2. 결측치 확인 후.. 어떻게 해야 하지?
#
#   . 해당 행을 삭제 하거나,
#   . 통계값 ( 평균값, 최대, 최소, 최빈 등)으로 대체
#   . 근처값으로 대체
#
#   등으로 처리.

# %%
## 결측치가 있는 항을 제거해 보자.  dropna (axis = 0 ) // 세로를 기준으로, 결측치가 있는 행을 제거

df_1 = df.dropna(axis=0)
df_1.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df_1.shape   # 데이터 프레림 크기
# Out:
# (183, 12)

# %% [markdown]
# ### dropna () 함수와  axis 사용
#
#   결측치가 있는 모든 행 삭제  : df.dropna(axis = 0 )
#   결측치가 있는 모든 열 삭제  : df.dropna(axis = 1 )
#   Age 열의 결측치가 있는 모든 행 삭제 : df.dropana(subset=["Age"],axis = 0 )

# %%
df_2 = df.dropna(axis=1)
df_2.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# dtype: int64

# %%
print(df["Age"].isnull().sum())
# Out:
# 177

# %%
age_mean = df["Age"].mean()

# %% [markdown]
# 3. 결측치 대체
#    fillna() 함수를 이용해서 NaN 값을 대체
#
#     1). 결측치를 지정한 값으로 대체
#
#     2). 결측치를 인접한 값으로 대체

# %%
df.fillna({"Age":age_mean}, inplace=True)  # 평균으로 데체. inplace 덮어 씌워라.

# %%
print(df["Age"].isnull().sum())
# Out:
# 0

# %%
## Embark column의 최빈 값으로 대체
## mode (최빈값)

# %%
from scipy.stats import mode
print(df["Embarked"].isnull().sum())
# Out:
# 2

# %%
embarked_mode = df["Embarked"].mode()
print(embarked_mode)
# Out:
# 0    S
# Name: Embarked, dtype: object

# %%
age_mode = df['Age'].mode()
print(age_mode)
# Out:
# 0    29.699118
# Name: Age, dtype: float64

# %%
sex_mode = df['Sex' ].mode()
print(sex_mode)
# Out:
# 0    male
# Name: Sex, dtype: object

# %%
age_mean = df['Age'].mean()
print(age_mean)
df["Age"].fillna(age_mean)
df
# Out:
# 29.69911764705882
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ...

# %%
df["Embarked"].fillna(embarked_mode, inplace=True)
# Out:
# <ipython-input-229-a2e9c29888b1>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Embarked"].fillna(embarked_mode, inplace=True)

# %%
print(df["Embarked"].isnull().sum())  ## 결과값은 0번 방에 저장하기 때문에 index 0이 보인다.
# Out:
# 2

# %%
## mode는 index와 value로 구성되기 때문에 결과는 0, value로 나온다.

# %% [markdown]
# 인접한 값으로 대체 (직전행

# %%
## Embark 인접한 값으로 대체  ( ffill,  bfill ) 등 함수 사용 // f :forward fill, b: backward fill
## forward 는 이전값에서 넘어왔다로 이해.
## backward 는 앞의 값에서 넘어 왔다로 이해. ( 즉  결측값이 있는 것을 기준으로 어떻게 땡켜 올 것인가?)

# %%
df["Embarked"].fillna(method="ffill", inplace=True)
# Out:
# <ipython-input-233-9e20475fa5cd>:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df["Embarked"].fillna(method="ffill", inplace=True)

# %%
df["Embarked"] = df["Embarked"].ffill()

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df_new = df.drop('Cabin', axis=1)
df_new
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
import pandas as pd


# 생존자 중 여성만 필터링
female_survivors = df[(df['Survived'] == 1) & (df['Sex'] == 'female')]

female_survivors["Survived"].count()
print("생존한 여성의 수:", len(female_survivors))

# 생존자 중 남성만 필터링
male_survivors = df[(df['Survived'] == 1) & (df['Sex'] == 'male')]

male_survivors["Survived"].count()
print("생존한 남성의 수:", len(male_survivors))


# 생존자 중 여성만 필터링
female_survivors = df[(df['Survived'] == 0) & (df['Sex'] == 'female')]

female_survivors["Survived"].count()
print("사망한 여성의 수:", len(female_survivors))

# 생존자 중 남성만 필터링
male_survivors = df[(df['Survived'] == 0) & (df['Sex'] == 'male')]

male_survivors["Survived"].count()
print("사망한 남성의 수:", len(male_survivors))
# Out:
# 생존한 여성의 수: 233
# 생존한 남성의 수: 109
# 사망한 여성의 수: 81
# 사망한 남성의 수: 468

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
dead_males = df[(df['Survived'] == 0) & (df['Sex'] == 'male')]
dead_males["Pclass"].size
# Out:
# 468

# %%
# 성별 숫자화 (optional)
df['Sex'] = df['Sex'].map({'male': 0, 'female': 1})

# 나이 구간 설정
df['AgeGroup'] = pd.cut(df['Age'], bins=[0, 12, 18, 35, 60, 100],
                        labels=['Child', 'Teen', 'Young', 'Adult', 'Senior'])

# 가족 수 계산
df['FamilySize'] = df['SibSp'] + df['Parch']

# 요금 구간 설정 (4등분)
df['FareGroup'] = pd.qcut(df['Fare'], q=4, labels=['Low', 'Mid', 'High', 'VeryHigh'])

# 필요한 열로 그룹화
group_cols = ['Sex', 'Pclass', 'AgeGroup', 'FamilySize', 'FareGroup']
# Out:
# ['Sex', 'Pclass', 'AgeGroup', 'FamilySize', 'FareGroup']

# %%
import pandas as pd



# 전처리
df['Sex'] = df['Sex'].map({'male': 0, 'female': 1})
df['AgeGroup'] = pd.cut(df['Age'], bins=[0, 12, 18, 35, 60, 100],
                        labels=['Child', 'Teen', 'Young', 'Adult', 'Senior'])
df['FamilySize'] = df['SibSp'] + df['Parch']
df['FareGroup'] = pd.qcut(df['Fare'], q=4, labels=['Low', 'Mid', 'High', 'VeryHigh'])

# 결측치 제거
df_clean = df.dropna(subset=['AgeGroup', 'FareGroup'])

# 그룹 조합별 생존률
group_cols = ['Sex', 'Pclass', 'AgeGroup', 'FamilySize', 'FareGroup']
grouped = df_clean.groupby(group_cols)['Survived'].mean().reset_index()

# 생존률 상위 10개
top10 = grouped.sort_values(by='Survived', ascending=False).head(10)

# 생존률 하위 10개
bottom10 = grouped.sort_values(by='Survived', ascending=True).head(10)

print("🎯 생존률 가장 높은 조합:")
print(top10)

print("\n🔻 생존률 가장 낮은 조합:")
print(bottom10)
# Out:
# 🎯 생존률 가장 높은 조합:
# Empty DataFrame
# Columns: [Sex, Pclass, AgeGroup, FamilySize, FareGroup, Survived]
# Index: []
#
# 🔻 생존률 가장 낮은 조합:
# Empty DataFrame
# Columns: [Sex, Pclass, AgeGroup, FamilySize, FareGroup, Survived]
# Index: []
# <ipython-input-254-70654beed5c3>:17: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = df_clean.groupby(group_cols)['Survived'].mean().reset_index()
